# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
sns.set(color_codes=True)

# %%
df=pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/9240474/14466861/developer_stress.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20260113%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20260113T040549Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
df.head(10)
# Out:
#    Hours_Worked  Sleep_Hours  Bugs  Deadline_Days  Coffee_Cups  Meetings  \
# 0            10            8    25             53            4         9
# 1             7            8    33             33            2         6
# 2            14            8    44             54           10        12
# 3            11            6     5             46            0        13
# 4             8            7    36             23            9         3
# 5            10            6    32             53            5         7
# 6            13            4    21             21            1         4
# 7             6            4    20              4            2         0
# 8            10            7     5             55            0         3
# 9            14            6     5             32            8         2
#
#    Interruptions Experience_Years Code_Complexity Remote_Work  Stress_Level
# 0              2           Senior          Medium         Yes     58.521033
# ...

# %%
df.tail(10)
# Out:
#      Hours_Worked  Sleep_Hours  Bugs  Deadline_Days  Coffee_Cups  Meetings  \
# 490             6            8    28             28            6         2
# 491            15            4    20             20            8        12
# 492            13            3    10             46            0        10
# 493             6            6    39             15           10        16
# 494             8            5    10             36            6        12
# 495             9            4    35             58            7         5
# 496            12            3    48             19            2        16
# 497            15            7    38              5            3        12
# 498             8            8    39             18            9        18
# 499             4            6    34             56            5        20
#
#      Interruptions Experience_Years Code_Complexity Remote_Work  Stress_Level
# ...

# %%
df.dtypes
# Out:
# Hours_Worked          int64
# Sleep_Hours           int64
# Bugs                  int64
# Deadline_Days         int64
# Coffee_Cups           int64
# Meetings              int64
# Interruptions         int64
# Experience_Years     object
# Code_Complexity      object
# Remote_Work          object
# Stress_Level        float64
# dtype: object

# %%
df=df.drop(columns=['Interruptions'])
df.head(10)
# Out:
#    Hours_Worked  Sleep_Hours  Bugs  Deadline_Days  Coffee_Cups  Meetings  \
# 0            10            8    25             53            4         9
# 1             7            8    33             33            2         6
# 2            14            8    44             54           10        12
# 3            11            6     5             46            0        13
# 4             8            7    36             23            9         3
# 5            10            6    32             53            5         7
# 6            13            4    21             21            1         4
# 7             6            4    20              4            2         0
# 8            10            7     5             55            0         3
# 9            14            6     5             32            8         2
#
#   Experience_Years Code_Complexity Remote_Work  Stress_Level
# 0           Senior          Medium         Yes     58.521033
# ...

# %%
df=df.rename(columns={"Experience_Years":"work_experience" , "Deadline_Days":"Dead_line" ,"Coffee_Cups":"Coffee" })
df.head(10)
# Out:
#    Hours_Worked  Sleep_Hours  Bugs  Dead_line  Coffee  Meetings  \
# 0            10            8    25         53       4         9
# 1             7            8    33         33       2         6
# 2            14            8    44         54      10        12
# 3            11            6     5         46       0        13
# 4             8            7    36         23       9         3
# 5            10            6    32         53       5         7
# 6            13            4    21         21       1         4
# 7             6            4    20          4       2         0
# 8            10            7     5         55       0         3
# 9            14            6     5         32       8         2
#
#   work_experience Code_Complexity Remote_Work  Stress_Level
# 0          Senior          Medium         Yes     58.521033
# 1          Junior          Medium         Yes     47.461651
# 2          Junior             Low          No     59.211580
# ...

# %%
df.shape
# Out:
# (500, 10)

# %%
duplicate_rows_df = df[df.duplicated()]
print("numbers of duplicated rows : " , duplicate_rows_df.shape)
# Out:
# numbers of duplicated rows :  (0, 10)

# %%
df.count()
# Out:
# Hours_Worked       500
# Sleep_Hours        500
# Bugs               500
# Dead_line          500
# Coffee             500
# Meetings           500
# work_experience    500
# Code_Complexity    500
# Remote_Work        500
# Stress_Level       500
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Hours_Worked       0
# Sleep_Hours        0
# Bugs               0
# Dead_line          0
# Coffee             0
# Meetings           0
# work_experience    0
# Code_Complexity    0
# Remote_Work        0
# Stress_Level       0
# dtype: int64

# %%
df=df.dropna()
df.count()
# Out:
# Hours_Worked       500
# Sleep_Hours        500
# Bugs               500
# Dead_line          500
# Coffee             500
# Meetings           500
# work_experience    500
# Code_Complexity    500
# Remote_Work        500
# Stress_Level       500
# dtype: int64

# %% [markdown]
# # outliers

# %%
sns.boxplot(x=df['Stress_Level'])
# Out:
# <Axes: xlabel='Stress_Level'>

# %%
sns.boxplot(x=df['Dead_line'])
# Out:
# <Axes: xlabel='Dead_line'>

# %%
df['Code_Complexity'].value_counts().plot(kind='bar', figsize=(10, 5), color='teal')

plt.xlabel('Complexity Level')
plt.ylabel('Count of Projects')
plt.title('Distribution of Code Complexity')
# Out:
# Text(0.5, 1.0, 'Distribution of Code Complexity')

# %%
plt.figure(figsize=(10,5))
c = df.corr(numeric_only=True)
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#               Hours_Worked  Sleep_Hours      Bugs  Dead_line    Coffee  \
# Hours_Worked      1.000000    -0.016861 -0.102563  -0.049388 -0.004005
# Sleep_Hours      -0.016861     1.000000  0.002387   0.043732  0.032011
# Bugs             -0.102563     0.002387  1.000000   0.012048 -0.026076
# Dead_line        -0.049388     0.043732  0.012048   1.000000  0.015704
# Coffee           -0.004005     0.032011 -0.026076   0.015704  1.000000
# Meetings         -0.013380    -0.078593 -0.020834   0.004069 -0.021275
# Stress_Level      0.289498    -0.677711  0.023585  -0.195973 -0.043098
#
#               Meetings  Stress_Level
# Hours_Worked -0.013380      0.289498
# Sleep_Hours  -0.078593     -0.677711
# Bugs         -0.020834      0.023585
# Dead_line     0.004069     -0.195973
# Coffee       -0.021275     -0.043098
# Meetings      1.000000      0.246943
# Stress_Level  0.246943      1.000000

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(df['Hours_Worked'], df['Stress_Level'])
ax.set_xlabel('Hours Worked')
ax.set_ylabel('Stress Level')
plt.show()
